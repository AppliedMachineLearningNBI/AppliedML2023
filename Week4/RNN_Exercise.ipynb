# %% [markdown]
# # RNN and Natural Language Processing
#
# In this exercise we will try to classify IMDB dataset: Given the text of a review, can you predict if the review was positive or negative?
#
# Before doing this exercise, you might want to become more familier with LSTMs by considering the example FlightPassengerPredictions.
#
# The data for this exercise can be found here:
# https://sid.erda.dk/share_redirect/encok5nw3y
#
# ***
#
# Author: Julius Kirkegaard and Troels C. Petersen<br>
# Date: 14th of May 2023

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import pickle
from collections import defaultdict
from torch import nn
import json
from torch.utils.data import DataLoader
from tqdm import tqdm
from itertools import chain
from collections import Counter

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cpu

# %% [markdown]
# ## Data

# %%
limit_data = 10000  # limit the amount of data for speed, change as you please

def remove_special_symbols(string):
    return ''.join(s for s in string if ord(s)>96 and ord(s)<123 or s == ' ')

with open('train.json') as f:
    train_text, train_labels = json.load(f)
    idxs = np.random.permutation(len(train_text))
    train_text = [remove_special_symbols(train_text[i]) for i in idxs[:limit_data]]
    train_labels = [train_labels[i] for i in idxs[:limit_data]]
    
with open('test.json') as f:
    test_text, test_labels = json.load(f)
    idxs = np.random.permutation(len(test_text))   
    test_text = [remove_special_symbols(test_text[i]) for i in idxs[:limit_data]]
    test_labels = [test_labels[i] for i in idxs[:limit_data]]

# %% [markdown]
# Let's have a look at the data... Here is a negative review (label = 0)

# %%
print(train_text[0])
print(train_labels[0])
# Out:
#  really have to disagree with guyyardleyrees who should he have watched the entire film would have seen some absolutely stunning cottish scenery some of the best ever shot in kye and found a film with a difficult start come together into a really poignant wholebr br his is not a big budget film ather it is a film that has a strong community feelbr br  cant say how much standard films bore me  pushing out the same polished stuff again and again eachd doesnt seem to be about that at all t really seems to be trying to offer something more real and certainly more aelic than any recent cottish filmbr br  so the acting isnt in the style a blockbuster hats because the actors are seemingly real people  actually thought that the key roles of the boy and his randfather were really convincing  and at times unusually beautifulbr br eachd really bears a second viewing since there are many threads that become clearer second time around  that really do feed into the endingbr br verall the combination of music and at times stunning visuals plus a community approach to the acting and nonnormal structure has turned eachd into quite a distinctive and memorable film ore of these please
# 1

# %% [markdown]
# And a positive one:

# %%
print(train_text[3])
print(train_labels[3])
# Out:
#  had tried to rent this on many occasions but was always with the girlfriend who as a general rule usually rejects heist flicks and ensemble comedies with the comment hm looks good but im not in the mood for that movie hus entereth the lmighty olo ovie ightbr br nyway  found elcome o ollinwood a rather enjoyable movie hile ultimately fairly forgettable it does have moments of fun and a few laugh out loud moments  was unfamiliar with the fact that it was a remake and as a general rule watch movies trying to ignore that fact and watch them on their own merits anyway eorge looney puts in a humorous and brief cameo as a wheeled safe cracker that for the most part left me wondering two things  wouldnt every comedy be better if r looney put in a strange  minute cameo and  ow do they make fake tattoos that look old and faded and how easily do they wash off he cast all fine actors in their own right put in a great job and you get the impression that they had a good time working together which is fairly important in a movie like this eedless to say all does not go as planned in this movie both plotwise and humorwise but it made me check out the special features and consider watching the original so  consider it a success ent this one for a good time maybe grab a few friends and a pizza youll have a good timebr br br br n a side note the soundtrack is spectacular ts great to hear the far under appreciated aolo onte used and it left me humming snippets of the score long after the credits rolled
# 1

# %% [markdown]
# ## Embedding

# %% [markdown]
# Let's have a look at all the words we have:

# %%
all_words = list(chain(*[x.lower().split() for x in train_text]))
print('total number of unique words =', len(set(all_words)))
# Out:
# total number of unique words = 74948

# %% [markdown]
# That's a lot of words... of course, we could clean the data even more if we wanted to. But we won't...
# (for instance, there are probably many misspelled words)

# %%
Counter(all_words)
# Out:
# Counter({'really': 4494,
#          'have': 10927,
#          'to': 53463,
#          'disagree': 45,
#          'with': 17272,
#          'guyyardleyrees': 1,
#          'who': 7875,
#          'should': 1968,
#          'he': 27833,
#          'watched': 867,
#          'the': 116444,
#          'entire': 581,
#          'film': 14841,
#          'would': 4796,
#          'seen': 2523,
#          'some': 5743,
#          'absolutely': 576,
#          'stunning': 154,
#          'cottish': 37,
#          'scenery': 151,
#          'of': 57960,
#          'best': 2314,
#          'ever': 2286,
#          'shot': 765,
#          'in': 35012,
#          'kye': 4,
#          'and': 62522,
#          'found': 1058,
#          'a': 62902,
#          'difficult': 269,
#          'start': 645,
#          'come': 1195,
#          'together': 839,
#          'into': 3661,
#          'poignant': 64,
#          'wholebr': 11,
#          'br': 23307,
#          'his': 16856,
#          'is': 43046,
#          'not': 11269,
#          'big': 1157,
#          'budget': 572,
#          'ather': 97,
#          'it': 26178,
#          'that': 27097,
#          'has': 6719,
#          'strong': 371,
#          'community': 95,
#          'feelbr': 5,
#          'cant': 1437,
#          'say': 2128,
#          'how': 3151,
#          'much': 3823,
#          'standard': 153,
#          'films': 3055,
#          'bore': 79,
#          'me': 4074,
#          'pushing': 36,
#          'out': 6469,
#          'same': 1586,
#          'polished': 33,
#          'stuff': 443,
#          'again': 1450,
#          'eachd': 3,
#          'doesnt': 1793,
#          'seem': 839,
#          'be': 10634,
#          'about': 6856,
#          'at': 8875,
#          'all': 8522,
#          't': 5575,
#          'seems': 1441,
#          'trying': 973,
#          'offer': 144,
#          'something': 1941,
#          'more': 5486,
#          'real': 1747,
#          'certainly': 539,
#          'aelic': 8,
#          'than': 3987,
#          'any': 3166,
#          'recent': 178,
#          'filmbr': 315,
#          'so': 6905,
#          'acting': 2502,
#          'isnt': 1210,
#          'style': 592,
#          'blockbuster': 49,
#          'hats': 467,
#          'because': 3285,
#          'actors': 1713,
#          'are': 11687,
#          'seemingly': 143,
#          'people': 3402,
#          'actually': 1624,
#          'thought': 1324,
#          'key': 139,
#          'roles': 420,
#          'boy': 444,
#          'randfather': 1,
#          'were': 4400,
#          'convincing': 205,
#          'times': 1208,
#          'unusually': 21,
#          'beautifulbr': 6,
#          'bears': 38,
#          'second': 648,
#          'viewing': 280,
#          'since': 1034,
#          'there': 4299,
#          'many': 2520,
#          'threads': 15,
#          'become': 587,
#          'clearer': 10,
#          'time': 4715,
#          'around': 1387,
#          'do': 3339,
#          'feed': 24,
#          'endingbr': 31,
#          'verall': 255,
#          'combination': 96,
#          'music': 1163,
#          'visuals': 105,
#          'plus': 169,
#          'approach': 166,
#          'nonnormal': 1,
#          'structure': 78,
#          'turned': 369,
#          'quite': 1482,
#          'distinctive': 17,
#          'memorable': 254,
#          'ore': 144,
#          'these': 1831,
#          'please': 259,
#          'realize': 262,
#          'alot': 16,
#          'hate': 291,
#          'this': 23997,
#          'movie': 16481,
#          'but': 13839,
#          'i': 1945,
#          'must': 1182,
#          'admit': 257,
#          'one': 9591,
#          'my': 4121,
#          'favorites': 66,
#          'happen': 400,
#          'like': 7743,
#          'better': 2212,
#          'then': 2558,
#          'its': 7429,
#          'predeccesor': 2,
#          'happy': 316,
#          'moviesbr': 53,
#          'irst': 387,
#          'off': 2200,
#          'think': 2851,
#          'never': 2429,
#          'give': 1290,
#          'story': 4451,
#          'credit': 214,
#          'ack': 446,
#          'uture': 16,
#          'ime': 111,
#          'ravel': 3,
#          'hard': 926,
#          'write': 245,
#          'they': 7184,
#          'included': 106,
#          'piritual': 2,
#          'ourneybr': 1,
#          'also': 3127,
#          'feel': 1120,
#          'eanu': 17,
#          'lex': 76,
#          'on': 13251,
#          'performances': 676,
#          'looked': 386,
#          'cooler': 12,
#          'acted': 221,
#          'said': 870,
#          'thingsbr': 12,
#          'set': 831,
#          'design': 120,
#          'awsome': 4,
#          'as': 18023,
#          'well': 3131,
#          'sets': 316,
#          'detailed': 44,
#          'massive': 75,
#          'can': 4259,
#          'believe': 997,
#          'made': 3074,
#          'for': 16909,
#          'two': 2475,
#          'teenage': 135,
#          'buds': 4,
#          'hardly': 232,
#          'spellbut': 1,
#          'genius': 184,
#          'whole': 1196,
#          'franchise': 54,
#          'making': 1005,
#          'idiots': 47,
#          'bigger': 94,
#          'life': 2282,
#          'characters': 2787,
#          'responsible': 108,
#          'utopian': 3,
#          'future': 333,
#          'earthbr': 8,
#          'costume': 76,
#          'was': 19289,
#          'ill': 580,
#          'ed': 307,
#          'look': 1574,
#          'cool': 315,
#          'ogus': 12,
#          'ourney': 21,
#          'where': 2325,
#          'xcellent': 38,
#          'dventure': 10,
#          'rather': 1059,
#          'put': 866,
#          'ven': 653,
#          'score': 420,
#          'especially': 908,
#          'here': 3986,
#          'could': 3048,
#          'cause': 175,
#          'love': 2273,
#          'ut': 3009,
#          'those': 1726,
#          'movies': 3093,
#          'grew': 101,
#          'up': 4867,
#          'watching': 1700,
#          'everytime': 5,
#          'did': 2365,
#          'liked': 582,
#          'understand': 665,
#          'why': 1517,
#          'or': 7776,
#          'just': 6490,
#          'compared': 206,
#          'adventure': 148,
#          'which': 4604,
#          'by': 8914,
#          'waybr': 74,
#          'worst': 1022,
#          'ones': 596,
#          'year': 726,
#          'main': 869,
#          'no': 4314,
#          'chemistry': 184,
#          'horrible': 441,
#          'aul': 328,
#          'udd': 49,
#          'only': 4548,
#          'talent': 348,
#          'annoying': 394,
#          'esparte': 1,
#          'ousewives': 8,
#          'dont': 2878,
#          'know': 2412,
#          'va': 50,
#          'ongoria': 23,
#          'show': 2420,
#          'she': 4116,
#          'ts': 2694,
#          'knows': 343,
#          'nothing': 1423,
#          'll': 1222,
#          'her': 7187,
#          'character': 2511,
#          'does': 2236,
#          'whine': 9,
#          'throughout': 509,
#          'pull': 136,
#          'being': 2499,
#          'b': 253,
#          'still': 2035,
#          'entertaining': 524,
#          'nd': 2820,
#          'other': 3603,
#          'girl': 985,
#          'ake': 275,
#          'ell': 766,
#          'displays': 53,
#          'little': 2498,
#          'emotion': 157,
#          'you': 10611,
#          'looking': 850,
#          'cue': 26,
#          'cards': 45,
#          'reads': 39,
#          'thembr': 111,
#          's': 3673,
#          'cookie': 14,
#          'cutter': 8,
#          'goes': 917,
#          'from': 7837,
#          'point': 1219,
#          'surprise': 289,
#          'o': 2725,
#          'been': 3739,
#          'used': 746,
#          'ate': 194,
#          'ghost': 136,
#          'plot': 2449,
#          'revolved': 11,
#          'things': 1368,
#          'spiritbr': 8,
#          'worth': 863,
#          'had': 4488,
#          'tried': 352,
#          'rent': 288,
#          'occasions': 29,
#          'always': 1207,
#          'girlfriend': 215,
#          'general': 235,
#          'rule': 63,
#          'usually': 356,
#          'rejects': 16,
#          'heist': 30,
#          'flicks': 133,
#          'ensemble': 58,
#          'comedies': 156,
#          'comment': 264,
#          'hm': 1,
#          'looks': 939,
#          'good': 5592,
#          'im': 514,
#          'mood': 159,
#          'hus': 47,
#          'entereth': 1,
#          'lmighty': 12,
#          'olo': 22,
#          'ovie': 181,
#          'ightbr': 4,
#          'nyway': 173,
#          'elcome': 15,
#          'ollinwood': 2,
#          'enjoyable': 327,
#          'hile': 582,
#          'ultimately': 177,
#          'fairly': 220,
#          'forgettable': 78,
#          'moments': 669,
#          'fun': 989,
#          'few': 1642,
#          'laugh': 477,
#          'loud': 161,
#          'unfamiliar': 19,
#          'fact': 1435,
#          'remake': 220,
#          'watch': 2430,
#          'ignore': 64,
#          'them': 3061,
#          'their': 4357,
#          'own': 1333,
#          'merits': 37,
#          'anyway': 224,
#          'eorge': 300,
#          'looney': 22,
#          'puts': 152,
#          'humorous': 100,
#          'brief': 144,
#          'cameo': 110,
#          'wheeled': 3,
#          'safe': 96,
#          'cracker': 7,
#          'most': 3183,
#          'part': 1482,
#          'left': 794,
#          'wondering': 162,
#          'wouldnt': 420,
#          'every': 1412,
#          'comedy': 1179,
#          'if': 4414,
#          'r': 1154,
#          'strange': 360,
#          'minute': 290,
#          'ow': 1146,
#          'make': 3037,
#          'fake': 192,
#          'tattoos': 1,
#          'old': 1638,
#          'faded': 16,
#          'easily': 310,
#          'wash': 19,
#          'cast': 1439,
#          'fine': 515,
#          'right': 1207,
#          'great': 3358,
#          'job': 862,
#          'get': 3572,
#          'impression': 162,
#          'working': 304,
#          'important': 348,
#          'eedless': 46,
#          'go': 1772,
#          'planned': 39,
#          'both': 1176,
#          'plotwise': 6,
#          'humorwise': 1,
#          'check': 233,
#          'special': 794,
#          'features': 255,
#          'consider': 168,
#          'original': 1268,
#          'success': 232,
#          'ent': 55,
#          'maybe': 579,
#          'grab': 43,
#          'friends': 672,
#          'pizza': 16,
#          'youll': 413,
#          'timebr': 127,
#          'n': 3082,
#          'side': 505,
#          'note': 199,
#          'soundtrack': 286,
#          'spectacular': 107,
#          'hear': 288,
#          'far': 1095,
#          'under': 463,
#          'appreciated': 64,
#          'aolo': 2,
#          'onte': 12,
#          'humming': 8,
#          'snippets': 11,
#          'long': 1257,
#          'after': 2456,
#          'credits': 248,
#          'rolled': 30,
#          'chosen': 96,
#          'wasnt': 901,
#          'ollywood': 785,
#          'orst': 53,
#          'case': 586,
#          'needthistohappenorwehavenomovie': 1,
#          'scenario': 52,
#          'illis': 39,
#          'mission': 101,
#          'save': 352,
#          'doctor': 137,
#          'adamant': 3,
#          'missionary': 12,
#          'first': 3184,
#          'chopper': 4,
#          'marched': 4,
#          'refugees': 11,
#          'border': 45,
#          'without': 1147,
#          'e': 3076,
#          'compromised': 8,
#          'package': 24,
#          'works': 499,
#          'pointed': 56,
#          'we': 3204,
#          'drama': 485,
#          'reality': 385,
#          'complicated': 59,
#          'owever': 823,
#          'workable': 3,
#          'hat': 2022,
#          'done': 1146,
#          'battle': 241,
#          'scenes': 2022,
#          'waste': 540,
#          'ears': 118,
#          'un': 132,
#          'dvd': 18,
#          'rental': 75,
#          'fee': 9,
#          'heck': 126,
#          'rainy': 21,
#          'day': 880,
#          'satisfied': 34,
#          'udicrous': 1,
#          'violations': 2,
#          'basic': 167,
#          'security': 61,
#          'regs': 2,
#          'beginning': 554,
#          'see': 4245,
#          'achieved': 59,
#          'such': 1984,
#          'abysmal': 40,
#          'trash': 170,
#          'low': 521,
#          'once': 746,
#          'got': 1314,
#          'curious': 91,
#          'worse': 518,
#          'possibly': 271,
#          'version': 780,
#          'play': 847,
#          'several': 532,
#          'stage': 238,
#          'apart': 216,
#          'moviebr': 320,
#          'very': 5585,
#          'nice': 744,
#          'idea': 768,
#          'merican': 768,
#          'outh': 159,
#          'credible': 71,
#          'backdrop': 54,
#          'extreme': 130,
#          'reaction': 100,
#          'round': 105,
#          'eros': 8,
#          'supposed': 601,
#          'misdemeanourbr': 1,
#          'execution': 74,
#          'iddoes': 2,
#          'mannered': 17,
#          'eatrice': 9,
#          'giving': 339,
#          'particularly': 422,
#          'poor': 714,
#          'performance': 1160,
#          'aterston': 3,
#          'actor': 840,
#          'enedictbr': 1,
#          'poorest': 11,
#          'role': 1283,
#          'ohn': 800,
#          'makes': 1661,
#          'eeves': 27,
#          'erhaps': 221,
#          'desire': 102,
#          'caricature': 30,
#          'along': 580,
#          'lines': 595,
#          'villain': 225,
#          'ties': 30,
#          'maiden': 13,
#          'train': 137,
#          'track': 146,
#          'fits': 82,
#          'keystone': 1,
#          'kops': 1,
#          'capers': 2,
#          'ogberry': 1,
#          'men': 670,
#          'want': 1424,
#          'cringebr': 2,
#          'uccessful': 3,
#          'setups': 12,
#          'include': 150,
#          'scene': 2087,
#          'fool': 54,
#          'enedict': 4,
#          'believing': 51,
#          'loves': 167,
#          'him': 3428,
#          'competent': 53,
#          'superb': 247,
#          'use': 726,
#          'river': 86,
#          'visual': 178,
#          'humour': 188,
#          'moving': 329,
#          'closer': 82,
#          'producedbr': 4,
#          'force': 163,
#          'myself': 436,
#          'keep': 613,
#          'didnt': 1726,
#          'attentionbr': 7,
#          'ery': 168,
#          'disappointingbr': 7,
#          'ith': 485,
#          'respect': 190,
#          'latter': 140,
#          'comments': 289,
#          'above': 329,
#          'am': 1363,
#          'nearly': 302,
#          've': 1312,
#          'screen': 846,
#          'productions': 56,
#          'hakespeare': 96,
#          'over': 2106,
#          'decades': 70,
#          'ight': 292,
#          'suggest': 152,
#          'when': 4705,
#          'defend': 40,
#          'your': 2134,
#          'speak': 192,
#          'piece': 622,
#          'attack': 141,
#          'reviewers': 107,
#          'inadequately': 2,
#          'armed': 41,
#          'terms': 165,
#          'assume': 98,
#          'though': 1673,
#          'distaste': 5,
#          'regarding': 69,
#          'youth': 100,
#          'sufficient': 14,
#          'age': 545,
#          'bygone': 7,
#          'days': 432,
#          'tastebr': 6,
#          'y': 1119,
#          'personal': 260,
#          'favourite': 133,
#          'pairing': 24,
#          'ylance': 1,
#          'ceer': 4,
#          'ondon': 139,
#          'nlike': 68,
#          'skilled': 13,
#          'charismatic': 56,
#          'performer': 43,
#          'act': 483,
#          'heard': 413,
#          'purchasing': 10,
#          'flick': 458,
#          'nuff': 4,
#          'told': 372,
#          'evils': 29,
#          'xperiment': 10,
#          'naturally': 65,
#          'went': 552,
#          'ahead': 140,
#          'ordered': 32,
#          'uinea': 5,
#          'ig': 211,
#          'box': 216,
#          'interested': 245,
#          'harlie': 186,
#          'heen': 12,
#          'ban': 8,
#          'either': 759,
#          'interest': 402,
#          'peakedbr': 1,
#          'short': 654,
#          'development': 238,
#          'ust': 472,
#          'torturing': 14,
#          'woman': 1015,
#          'minutes': 1102,
#          'hey': 1267,
#          'torture': 115,
#          'various': 237,
#          'ways': 317,
#          'beating': 52,
#          'spinning': 20,
#          'circles': 16,
#          'forcing': 34,
#          'drink': 55,
#          'alcohol': 34,
#          'listen': 131,
#          'hipitched': 2,
#          'noise': 44,
#          'hours': 364,
#          'smash': 14,
#          'hand': 415,
#          'mallet': 1,
#          'burning': 51,
#          'putting': 145,
#          'maggots': 7,
#          'burns': 15,
#          'throwing': 74,
#          'guts': 52,
#          'shoving': 8,
#          'sharp': 91,
#          'needle': 3,
#          'through': 1916,
#          'eyebr': 10,
#          'lot': 1616,
#          'grossing': 3,
#          'spun': 7,
#          'dizzy': 5,
#          'forced': 289,
#          'painful': 158,
#          'eye': 222,
#          'shutter': 2,
#          'simply': 773,
#          'amn': 13,
#          'pretty': 1393,
#          'enjoy': 670,
#          'recommend': 656,
#          'unless': 206,
#          'what': 4774,
#          'horror': 1234,
#          'genre': 437,
#          'm': 1841,
#          'dog': 203,
#          'find': 1629,
#          'totally': 504,
#          'spite': 67,
#          'production': 661,
#          'quality': 483,
#          'herein': 8,
#          'abominable': 9,
#          'monster': 196,
#          'stalking': 25,
#          'although': 607,
#          'itself': 609,
#          'doneimpressively': 1,
#          'kind': 1052,
#          'otherworldly': 6,
#          'an': 9373,
#          'alien': 102,
#          'family': 1170,
#          'vacation': 56,
#          'landed': 24,
#          'imalayas': 8,
#          'while': 1542,
#          'dad': 118,
#          'taking': 323,
#          'attending': 24,
#          'natures': 11,
#          'call': 344,
#          'pot': 28,
#          'loose': 103,
#          'hunt': 47,
#          'down': 1328,
#          'hes': 1061,
#          'aucasian': 4,
#          'brother': 360,
#          'ishmaster': 1,
#          'havent': 284,
#          'decided': 266,
#          'whichbr': 2,
#          'ctually': 97,
#          'filmed': 255,
#          'somewhere': 178,
#          'snow': 28,
#          'country': 321,
#          'yes': 308,
#          'likely': 173,
#          'anada': 52,
#          'hina': 80,
#          'anywhere': 114,
#          'trees': 31,
#          'vistas': 8,
#          'okay': 170,
#          'area': 127,
#          'takes': 866,
#          'ubercoldness': 1,
#          'might': 1173,
#          'expect': 444,
#          'cii': 74,
#          'hannel': 60,
#          'forgive': 58,
#          'lack': 582,
#          'locationbr': 3,
#          'urther': 11,
#          'apparently': 264,
#          'established': 73,
#          'directors': 340,
#          'travel': 97,
#          'often': 611,
#          'aware': 103,
#          'commercial': 99,
#          'planes': 16,
#          'fly': 85,
#          'weather': 21,
#          'featured': 78,
#          'subsequent': 53,
#          'crash': 57,
#          'happened': 418,
#          'graphic': 87,
#          'rotates': 1,
#          'between': 1391,
#          'live': 583,
#          'onner': 20,
#          'arty': 87,
#          'redator': 7,
#          'woods': 113,
#          'bad': 3370,
#          'wushu': 1,
#          'wires': 12,
#          'eti': 28,
#          'leap': 18,
#          'pidermanor': 1,
#          'uper': 38,
#          'arioremember': 1,
#          'faster': 27,
#          'ump': 18,
#          'higher': 97,
#          'ive': 220,
#          'longer': 202,
#          'lso': 570,
#          'missed': 225,
#          'teddy': 10,
#          'bear': 73,
#          'es': 659,
#          'searched': 17,
#          'high': 647,
#          'cannot': 413,
#          'cadaver': 2,
#          'work': 1637,
#          'oor': 49,
#          'ou': 1123,
#          'help': 724,
#          'sorry': 256,
#          'survived': 32,
#          'evolved': 16,
#          'thousands': 58,
#          'years': 1764,
#          'succumb': 4,
#          'severe': 34,
#          'loss': 121,
#          'wants': 518,
#          'mate': 30,
#          'ya': 34,
#          'unmated': 1,
#          'male': 257,
#          'superhuman': 8,
#          'humanits': 1,
#          'supereti': 1,
#          'whats': 230,
#          'normaleti': 1,
#          'definite': 40,
#          'ichael': 482,
#          'eyers': 12,
#          'completely': 790,
#          'unsettling': 42,
#          'fabulous': 56,
#          'way': 3077,
#          'cleaning': 22,
#          'fur': 12,
#          'ulous': 1,
#          'ahlink': 1,
#          'spotlessly': 1,
#          'white': 381,
#          'shouldnt': 124,
#          'fastidiously': 1,
#          'superhusuperetibr': 1,
#          'kills': 213,
#          'honest': 172,
#          'elements': 278,
#          'horribly': 78,
#          'gravellike': 1,
#          'theyre': 443,
#          'planning': 46,
#          'another': 1497,
#          'rates': 34,
#          'calebr': 1,
#          'cale': 2,
#          'frombr': 19,
#          'iend': 9,
#          'simplistic': 33,
#          'engaging': 126,
#          'heroine': 87,
#          'started': 363,
#          'arpenter': 35,
#          'brings': 253,
#          'nailbiting': 5,
#          'nightmare': 59,
#          'alloween': 92,
#          'night': 603,
#          'aurie': 30,
#          'trode': 4,
#          'amie': 51,
#          'ee': 448,
#          'urtis': 63,
#          'debut': 98,
#          'career': 374,
#          'defining': 9,
#          'mischievous': 14,
#          'plan': 147,
#          'sneaky': 7,
#          'cross': 90,
#          'paths': 19,
#          'relentless': 29,
#          'psychopath': 24,
#          'hell': 353,
#          'yers': 50,
#          'escaped': 39,
#          'nearby': 35,
#          'insane': 93,
#          'aslyumhaving': 1,
#          'slaughtered': 16,
#          'sister': 278,
#          'fifteen': 46,
#          'earlier': 255,
#          'now': 1280,
#          'back': 1832,
#          'addonfield': 2,
#          'sleepy': 15,
#          'llinois': 6,
#          'town': 448,
#          'murder': 369,
#          'took': 421,
#          'place': 899,
#          'nce': 167,
#          'eyes': 404,
#          'drops': 31,
#          'abandoned': 75,
#          'house': 599,
#          'lived': 132,
#          'begins': 315,
#          'stalk': 6,
#          'terrorize': 5,
#          'turning': 142,
#          'terror': 47,
#          'picks': 62,
#          'anyone': 902,
#          'path': 80,
#          'herbr': 57,
#          'eautiful': 34,
#          'cinematography': 359,
#          'lighting': 122,
#          'moody': 35,
#          'scary': 335,
#          'gloomy': 15,
#          'shots': 373,
#          'constantly': 151,
#          'feels': 329,
#          'youre': 698,
#          'stalked': 21,
#          'maniacal': 14,
#          'serial': 137,
#          'killer': 448,
#          'himself': 885,
#          'hidden': 104,
#          'until': 680,
#          'fully': 153,
#          'revealed': 82,
#          'exciting': 187,
#          'conclusionbr': 12,
#          'lthough': 361,
#          'outdated': 27,
#          'means': 322,
#          'less': 731,
#          'chilling': 62,
#          'alone': 401,
#          'goose': 12,
#          'bump': 13,
#          'inducing': 14,
#          'shocker': 17,
#          'famous': 294,
#          'spawned': 10,
#          'seven': 78,
#          'sequels': 86,
#          'eventually': 252,
#          'ob': 197,
#          'ombies': 33,
#          'equally': 155,
#          'new': 1200,
#          'exists': 58,
#          'today': 336,
#          'specially': 97,
#          'action': 1210,
#          'enjoyed': 480,
#          'eanlaude': 8,
#          'ammes': 9,
#          'including': 427,
#          'clone': 23,
#          'plays': 866,
#          'twins': 37,
#          'three': 741,
#          'cyborg': 12,
#          'fashion': 138,
#          'designer': 27,
#          'fight': 415,
#          'truck': 64,
#          'full': 587,
#          'durians': 1,
#          'ey': 96,
#          'else': 741,
#          'ass': 94,
#          'almost': 1188,
#          'even': 4355,
#          'pause': 17,
#          'zoom': 16,
#          'trust': 97,
#          'lan': 179,
#          'itizen': 45,
#          'anebr': 7,
#          'verything': 121,
#          'nake': 12,
#          'ater': 121,
#          'script': 1220,
#          'fights': 110,
#          'stunts': 59,
#          'spectacularly': 17,
#          'earthtimebendingly': 1,
#          'probably': 1074,
#          'showcasing': 5,
#          'socalled': 68,
#          'orenzo': 15,
#          'amas': 22,
#          'thats': 1090,
#          'saying': 367,
#          'd': 654,
#          'willing': 120,
#          'bet': 102,
#          'everyone': 748,
#          ...})

# %%
n_words = 25000   # let's make a model that only understand 25000 words

# %%
words, count = np.unique(all_words, return_counts=True)
idxs = np.argsort(count)[-n_words:]
vocab = ['<UNK>'] + list(words[idxs][::-1])
print(vocab[:5], '...', vocab[-5:])
# Out:
# ['<UNK>', 'the', 'a', 'and', 'of'] ... ['yoursbr', 'beatles', 'stripclub', 'stripes', 'onhamarter']

# %% [markdown]
# Not very surprisingly, the most commonly used word is _the_. The 25000th most used word is _chimneys_. We have added a special word `<UNK>` which we will used to mark words outside our vocabulary.

# %% [markdown]
# We can now turn a sentence into a sequence of integers that correspond to the position in the vocab.

# %%
vocab_d = {vocab[i]: i for i in range(len(vocab))}  # for quick look-up
def sentence_to_integer_sequence(s):
    return torch.tensor([vocab_d[x] if x in vocab_d else 0 for x in s.split()], dtype=torch.long)

# %%
sentence_to_integer_sequence("i really liked the movie xenopus51")
# Out:
# tensor([143,  56, 421,   1,  18,   0])

# %% [markdown]
# #### Representing high dimensional spaces with a simpler (learnable) embedding:
#
# We are now representing words in a "25000"-dimensional space: we have a unique integer for each word we can represent. To reduce this complexity, we instead intend to represent each word as a 50-dimensional real vector. Pytorch to the rescue:

# %%
embedding = nn.Embedding(len(vocab), 50)

# %% [markdown]
# `nn.Embedding` assigns are random, **but trainable** vector to each word. For instance:

# %%
print(embedding(sentence_to_integer_sequence("movie")))
# Out:
# tensor([[ 0.4881, -0.0029, -0.1876, -0.5179,  0.4515, -1.1402,  1.5735, -0.0110,
#          -1.3785,  0.6314,  2.2267,  0.4240, -1.0660, -0.3033,  0.0306,  0.3344,
#           1.4658, -0.0479, -0.6608,  0.1049,  0.7835, -0.1623,  1.1444,  0.9846,
#           0.4603,  1.0205, -2.0119, -1.2422,  1.6663,  0.5825, -1.9271, -1.1698,
#          -0.7586,  0.1706, -1.2880,  1.2837, -1.5307, -2.1710,  0.7318, -2.7492,
#          -1.1494,  0.1715,  0.5571, -0.6990,  0.6971, -0.7531,  0.6472, -0.4681,
#           0.5629,  0.3255]], grad_fn=<EmbeddingBackward>)

# %% [markdown]
# The special `<UNK>` word, which signifies unknown we can choose to zero out:

# %%
embedding.weight.data[0, :] = 0

# %% [markdown]
# Here is an example of how we represent a sentence then:

# %%
print(embedding(sentence_to_integer_sequence("i really liked the movie xenopus51")).shape)
print(embedding(sentence_to_integer_sequence("i really liked the movie xenopus51")))
# Out:
# torch.Size([6, 50])
# tensor([[ 5.5641e-01, -1.6343e+00,  1.0628e+00, -1.9976e-02,  3.3113e-01,
#           1.8641e+00, -6.5232e-01, -8.9025e-01,  3.0268e-01,  5.7124e-01,
#           1.0920e+00,  3.2339e-01, -4.3906e-01, -6.8665e-01,  3.9110e-02,
#           9.7126e-01,  2.5054e+00, -4.2875e-01,  8.8234e-02,  1.0390e+00,
#          -6.1140e-01, -1.5174e-01, -1.2417e+00,  1.9044e+00, -1.0692e+00,
#           9.5485e-01,  1.4346e+00, -2.7633e-01, -1.5929e+00, -1.8759e+00,
#           4.8675e-02,  1.1139e+00,  1.1466e+00, -4.5798e-02,  1.0682e+00,
#           7.2928e-01, -2.0445e-01, -7.0702e-02,  3.6502e-01, -1.5810e+00,
#           7.2825e-01, -1.5468e-01,  6.4691e-01,  7.4563e-01,  6.1608e-02,
#          -2.4876e-01, -1.2650e+00, -3.1478e-01, -2.3173e+00, -8.7808e-01],
#         [ 9.6347e-01,  1.7825e-01,  3.2580e-01, -1.7448e+00,  4.0648e-01,
#           3.3872e-01, -3.3913e-02, -1.1948e+00,  5.7852e-01, -5.8138e-01,
#           1.7930e+00, -6.4690e-01, -1.1121e+00, -2.0914e-01,  7.0068e-01,
#           2.1571e-01, -4.8716e-02, -5.9145e-01,  9.3693e-02, -1.5280e+00,
#          -5.6105e-01,  3.1214e-01,  8.1613e-01,  2.0694e+00, -8.9781e-01,
#           1.4985e-01, -6.7338e-01,  6.1297e-01,  3.6685e+00,  1.1297e+00,
#           9.5600e-01,  4.4340e-01,  5.3609e-01, -8.4645e-01,  9.3625e-01,
#          -1.9582e+00, -1.5388e+00, -6.6756e-01, -4.0324e-01, -4.6436e-02,
#           4.1401e-01, -9.6225e-01,  6.9917e-02,  8.7761e-01, -9.1291e-01,
#          -2.6998e-01,  1.0074e-01, -9.0678e-01,  9.7220e-01,  1.9748e-01],
#         [-3.2186e-01,  9.4578e-01, -6.6294e-02,  5.5625e-01,  1.4023e-01,
#          -7.5433e-01, -4.9962e-01, -8.1105e-01,  1.0202e+00,  9.8945e-02,
#          -7.8957e-01, -8.5577e-01,  1.0889e+00,  4.9513e-01,  1.2207e+00,
#          -9.3567e-01,  1.2386e+00,  6.2274e-01, -8.1284e-01, -1.2300e+00,
#          -7.6898e-01, -4.4447e-01,  6.3820e-01,  1.1405e+00,  6.2551e-01,
#           3.9656e-01, -2.7691e-01,  4.7524e-01, -2.0676e+00,  8.4023e-01,
#          -2.7758e-02, -2.2004e+00, -1.4209e+00,  9.0984e-02, -6.2942e-01,
#           8.1398e-01,  2.0352e+00,  1.0157e-01,  1.3249e+00,  6.1490e-02,
#           3.0937e-01,  5.7157e-01,  3.3949e-01, -2.9721e-01,  9.7570e-01,
#          -1.2150e+00, -1.0198e+00,  8.5225e-01,  1.0266e-01,  8.0663e-01],
#         [-8.5193e-02, -8.5558e-02,  1.0711e+00, -7.4388e-02,  9.8089e-01,
#          -1.2131e+00,  3.3526e-01, -1.6125e-01,  8.0723e-01, -7.9006e-02,
#          -1.8282e+00, -6.9276e-01,  1.2219e+00,  1.3790e-01, -2.3160e+00,
#           6.0817e-01, -1.4297e-01,  6.6898e-01,  4.0477e-01, -1.1741e+00,
#          -4.6087e-01, -1.2267e+00, -1.8456e+00,  5.2864e-01, -1.1369e+00,
#           1.2554e+00,  4.7744e-01,  1.2606e+00,  9.0606e-01, -1.1104e+00,
#           4.2905e-01, -7.2558e-01, -5.0439e-01,  1.1538e+00,  3.8813e-01,
#           5.9014e-01, -1.4255e+00,  1.1591e+00,  7.8442e-01, -1.1000e+00,
#          -1.3575e+00,  1.0169e+00, -1.0381e-01,  1.4953e+00, -7.2385e-01,
#           1.3863e-01, -8.9848e-01,  8.3454e-01,  8.9637e-02,  5.6195e-01],
#         [ 4.8807e-01, -2.8847e-03, -1.8757e-01, -5.1794e-01,  4.5149e-01,
#          -1.1402e+00,  1.5735e+00, -1.1044e-02, -1.3785e+00,  6.3136e-01,
#           2.2267e+00,  4.2399e-01, -1.0660e+00, -3.0325e-01,  3.0586e-02,
#           3.3437e-01,  1.4658e+00, -4.7922e-02, -6.6083e-01,  1.0486e-01,
#           7.8347e-01, -1.6227e-01,  1.1444e+00,  9.8456e-01,  4.6028e-01,
#           1.0205e+00, -2.0119e+00, -1.2422e+00,  1.6663e+00,  5.8251e-01,
#          -1.9271e+00, -1.1698e+00, -7.5859e-01,  1.7061e-01, -1.2880e+00,
#           1.2837e+00, -1.5307e+00, -2.1710e+00,  7.3179e-01, -2.7492e+00,
#          -1.1494e+00,  1.7146e-01,  5.5708e-01, -6.9901e-01,  6.9711e-01,
#          -7.5311e-01,  6.4724e-01, -4.6811e-01,  5.6295e-01,  3.2549e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]],
#        grad_fn=<EmbeddingBackward>)

# %% [markdown]
# In this way, the sentence bascially becomes a 6x50 pixel image.

# %% [markdown]
# You can now use `nn.LSTM` after an embedding to define a neural network for sentenes.
#
# This network will have a _lot_ of parameters. For each word, 50 parameters needs to be trained, and then comes the LSTM on top of that.
# This is the reason that _transfer learning_ is so important in natural language processing (NLP).
#
# Perhaps the simplest form of transfer learning is to use a pretrained embedding layer.

# %%
with open('glove.6B.50d.pkl', 'rb') as f:
    glove = pickle.load(f)

# %%
glove['movie']
# Out:
# array([ 0.30824 ,  0.17223 , -0.23339 ,  0.023105,  0.28522 ,  0.23076 ,
#        -0.41048 , -1.0035  , -0.2072  ,  1.4327  , -0.80684 ,  0.68954 ,
#        -0.43648 ,  1.1069  ,  1.6107  , -0.31966 ,  0.47744 ,  0.79395 ,
#        -0.84374 ,  0.064509,  0.90251 ,  0.78609 ,  0.29699 ,  0.76057 ,
#         0.433   , -1.5032  , -1.6423  ,  0.30256 ,  0.30771 , -0.87057 ,
#         2.4782  , -0.025852,  0.5013  , -0.38593 , -0.15633 ,  0.45522 ,
#         0.04901 , -0.42599 , -0.86402 , -1.3076  , -0.29576 ,  1.209   ,
#        -0.3127  , -0.72462 , -0.80801 ,  0.082667,  0.26738 , -0.98177 ,
#        -0.32147 ,  0.99823 ])

# %% [markdown]
# These pretrained word embeddings will have a good structure to them. For instance:

# %%
print('Distance b/w queen and prince =', np.linalg.norm(glove['queen'] - glove['prince']))
print('Distance b/w movie and prince =', np.linalg.norm(glove['movie'] - glove['prince']))
# Out:
# Distance b/w queen and prince = 3.3926491063677284
# Distance b/w movie and prince = 6.450784821820618

# %% [markdown]
# You can even sometimes get away with doing algebra with these vectors:

# %%
queenlike = glove['king'] - glove['man'] + glove['woman']

# %%
print('Distance b/w queen and algebraic queen =', np.linalg.norm(glove['queen'] - queenlike))
print('Distance b/w queen and king =', np.linalg.norm(glove['queen'] - glove['king']))
# Out:
# Distance b/w queen and algebraic queen = 2.8391206432941996
# Distance b/w queen and king = 3.4777562289742345

# %% [markdown]
# We can fill out our embedding layer using these pretrained vectors:

# %%
filled = 0
not_found = []
for i, w in enumerate(vocab):
    if w in glove:
        embedding.weight.data[i, :] = torch.tensor(glove[w], dtype=torch.float)
        filled += 1
    else:
        not_found.append(w)
print(f'Of the words in the vocab, {100 * filled / (len(vocab) - 1)} % were updated using Glove vectors')
print('Examples of words not found :', not_found[1:7])
# Out:
# Of the words in the vocab, 73.844 % were updated using Glove vectors
# Examples of words not found : ['owever', 'ichael', 'itbr', 'aybe', 'nglish', 'nfortunately']

# %% [markdown]
# Clearly the words we do not find are due to misspellings. You now have three choices before you continue with the exercise:
#
# (1) Use _hunspell_ or similar to fix misspelled words
#
# (2) Change the vocabulary (`vocab`) to be based on words that are both frequent in the text and have glove vectors
#
# (3) Ignore the issue.

# %% [markdown]
# Finally, with Glove vectors we do not need to train the embedding. We can consider it fixed:

# %%
embedding.requires_grad_(False)
# Out:
# Embedding(25001, 50)

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Train a neural network using `nn.LSTM` layers to classify the IMDB reviews.
#
# Ideas:
#
#  - The sentences can be quite long, so you might want to limit them to, say, maximum 100 words
#  - `nn.LSTM` can take batched input, but be careful with `batch_first=True/False`.
#  - If batched input are used, they normally have to be equal in size. You can put sentences to always be 100 words long, by adding `<UNK>` words to short sentences.
#  - Alternatively, `nn.LSTM` can also accept batched, variable-length input using `torch.nn.utils.rnn.pack_sequence`.
#  - (a finaly, albeit slow, alternative is to simple run the LSTM on un-batched input)

# %% [markdown]
# ## Language model

# %% [markdown]
# Often in NLP, a lot of unlabelled text is available. We can use this to pretrain the model, before fine-tuning to the task at hand.

# %%
with open('unlabelled.json') as f:
    text = json.load(f)
print(len(text))
# Out:
# 50000

# %% [markdown]
# A simple way to pretrain is to train a _language model_. This is a model that tries to predict the next word in a sentence. For instance, given:

# %%
" ".join(text[2].split()[:28])
# Out:
# 'This is still a pretty bad and silly simplistic typical slasher but when being compared to the previous sequel "Slumber Party Massacre II" this movie is a step'

# %% [markdown]
# can you guess the next word?

# %% [markdown]
# In a language model, we consider the above the input, and the output is:

# %%
text[2].split()[28]
# Out:
# 'up'

# %% [markdown]
# The input we encode using the embedding, while the output is a probability map over words.
# In other words, the last layer is something like `nn.Linear(..., len(vocab))`.

# %% [markdown]
# ### Exercise 2 (optional)

# %% [markdown]
# Train a language model.
#
# After you have trained the model, try to make to complete sentences.

# %% [markdown]
# ## Transfer learning
# ### Exercise 3 (optional)

# %% [markdown]
# Discard the last layer of the now trained language model and use it to train on the original IMDB-problem.
